# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
###Question 0

replace_na_mean= function(x){
    x[is.na(x)]=mean(x, na.rm=TRUE)  
}
data=c(1, NA, 2, 3, 2, 2, NA)
replace_na_mean(data) %>% print()

#replace the vector with the mean of that vector or replace the NA with the mean of the vector?
# Out:
# [1] 2

# %%
###Question 1

PIN4dig=expand.grid(0:9, 0:9, 0:9, 0:9)
nrow(PIN4dig)
# Out:
# [1] 10000

# %%
###Question 2

get_all_perms= function(x){
    if(is.null(x)){
        x<-4
    } else expand.grid(replicate(x,c(0:9),simplify=FALSE)) %>% nrow()
}
get_all_perms(1)
get_all_perms(2)
get_all_perms(3)
get_all_perms(4)
# Out:
# [1] 10
# [1] 100
# [1] 1000
# [1] 10000

# %%
###Question 3

#0 is healthy fish, 1 is diseased fish
diseased_fish= sample(c(0,1), size = 340, replace=TRUE, prob=c(1-.43,.43))
cat("diseased_fish says the number of diseased fish is: ", sum(diseased_fish))
# Out:
# diseased_fish says the number of diseased fish is:  161

# %%
###Question 4

x_vals=seq(8,12,0.05)
probs_1=mapply(dnorm, x_vals, mean=10, sd=0.1)
probs_2=mapply(dnorm, x_vals, mean=10.2, sd=0.1)

ggplot() + 
  geom_line(aes(x=x_vals, y=probs_1, color = "red"), size=2) +
  geom_line(aes(x=x_vals, y=probs_2, color = "blue"), size=2) +
  xlim(8,12)+
  theme(axis.title.x = element_text(size = 24), axis.title.y = element_text(size = 24)) + 
  theme(axis.text.x = element_text(size = 18), axis.text.y = element_text(size = 18)) + 
  scale_color_manual(labels = c("(10, 0.5)", "(10.2, 0.5)"), values = c("blue", "red"))

set.seed(42)

x_sample=sample(x_vals, 40, TRUE, probs_1)
y_sample=sample(x_vals, 40, TRUE, probs_2)

t.test(x_sample, y_sample)

#t-test reports not sig. different. Error in my code or am I misunderstanding the question?
#Is there an error in the code, since y-axis has whole values, not decimals/precents
# Out:
# 	Welch Two Sample t-test
#
# data:  x_sample and y_sample
# t = -7.808, df = 75.099, p-value = 2.744e-11
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.2400436 -0.1424564
# sample estimates:
# mean of x mean of y
#  10.02375  10.21500
# plot without title

# %%
#Question 5

x_vals=seq(8,12,0.1)
probs_1=mapply(dnorm, x_vals, mean=10, sd=0.5)

ggplot() + 
  geom_line(aes(x=x_vals, y=probs_1, color = "blue"), size=2) +
  xlim(8,12)+
  theme(axis.title.x = element_text(size = 24), axis.title.y = element_text(size = 24)) + 
  theme(axis.text.x = element_text(size = 18), axis.text.y = element_text(size = 18)) + 
  scale_color_manual(labels = c("(10, 0.5)"), values = c("blue"))

prob_dens=dnorm(5000,10,0.5)
prob_dens[seq(8,12,0.1)]
prob_dens2=rnorm(5000,10,0.5)
prob_dens2[seq(8,12,0.1)]
# Out:
#  [1] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
# [26] NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA
#  [1] 10.722051 10.722051 10.722051 10.722051 10.722051 10.722051 10.722051
#  [8] 10.722051 10.722051 10.722051  9.784277  9.784277  9.784277  9.784277
# [15]  9.784277  9.784277  9.784277  9.784277  9.784277  9.784277 10.327824
# [22] 10.327824 10.327824 10.327824 10.327824 10.327824 10.327824 10.327824
# [29] 10.327824 10.327824 10.160963 10.160963 10.160963 10.160963 10.160963
# [36] 10.160963 10.160963 10.160963 10.160963 10.160963  9.608081
# plot without title
